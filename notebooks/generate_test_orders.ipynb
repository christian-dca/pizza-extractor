# %% [markdown]
# Write a function that generates 10 pizza orders transcriptions.
# Only the turn when the customer orders the pizza.
# Make it as difficult as posible for the extractor,
# The output should be a python list.S
# Save the output to a text file.
#
# Use Anthropic "claude-haiku-4-5-20251001"
# and de Ollama:
# qwen3:4b-instruct
# qwen3:8b
