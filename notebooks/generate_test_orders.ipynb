# %%
from dotenv import load_dotenv
import os
import getpass

load_dotenv()

if "AWS_BEARER_TOKEN_BEDROCK" not in os.environ:
    os.environ["AWS_BEARER_TOKEN_BEDROCK"] = getpass.getpass("Introduce tu  AWS Key: ")

# %%
import os
from langchain.chat_models import init_chat_model

model = init_chat_model(
    "eu.amazon.nova-2-lite-v1:0",
    model_provider="bedrock_converse",
    max_tokens = 500
)

# %%
response = model.invoke("Why do parrots talk?")

# %%
response
# Out:
# AIMessage(content="### Why Do Parrots Talk?\n\nParrots talk primarily because of their highly developed **vocal learning** abilities, which are part of their natural communication system. While their ability to mimic human speech is often the most noticeable behavior, talking serves several important biological and social functions for parrots. Here's a breakdown of why parrots talk and what drives this behavior:\n\n---\n\n## 1. **Natural Communication**\n\n### **Vocal Learning and Social Interaction**\nParrots are **vocal learners**, similar to humans and some other animals like songbirds and cetaceans. They naturally use vocalizations to communicate with each other in the wild. These vocalizations include:\n\n- **Contact calls** – to locate flock members or signal safety.\n- **Alarming calls** – to warn of predators.\n- **Courtship calls** – to attract mates.\n- **Food-related calls** – to signal the discovery of food sources.\n\nThese calls are innate but can be modified through learning, especially during a parrot’s developmental period.\n\n---\n\n## 2. **Social Bonding**\n\n### **Parrots Are Social Animals**\nParrots are highly social creatures that live in flocks in the wild. Vocalizations help them:\n\n- **Maintain group cohesion** over long distances in dense forests.\n- **Form and strengthen social bonds** with flock mates.\n- **Establish hierarchies** and reduce conflict through vocal cues.\n\nWhen parrots are kept as pets, they often try to apply the same social logic — they seek companionship and will direct their vocalizations toward their human caregivers, expecting a response.\n\n---\n\n## 3. **Mimicry and Imitation**\n\n### **Learning Through Imitation**\nYoung parrots go through a **critical learning period** (often during their early months) where they imitate the sounds around them — including:\n\n- Other parrots (if raised in a flock or with recordings).\n- Human speech.\n- Environmental sounds (e.g., alarms, phones, TV).\n\nThis mimicry is not random — it’s a way to **learn appropriate communication**. If raised with humans, the parrot learns that human voices are part of its social environment and may imitate them in hopes of getting attention or a reaction.\n\n---\n\n## 4. **Expressing Needs and Emotions**\n\nParrots can learn to use specific vocalizations or words to **get what they want** or **express how they feel**. For example:\n\n- Saying “hungry” when they want food.\n- Saying “hello” to greet their owner.\n- Making a sound to", additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'd8d0b5aa-1c3e-48ce-bb9e-c4703bd7bcf0', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 07 Sep 2026 18:59:19 GMT', 'content-type': 'application/json', 'content-length': '2714', 'connection': 'keep-alive', 'x-amzn-requestid': 'd8d0b5aa-1c3e-48ce-bb9e-c4703bd7bcf0'}, 'RetryAttempts': 0}, 'stopReason': 'max_tokens', 'metrics': {'latencyMs': [3498]}, 'model_provider': 'bedrock_converse', 'model_name': 'eu.amazon.nova-2-lite-v1:0'}, id='lc_run--01a07d3d-2e4c-72e3-9918-b0532c6526b2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 51, 'output_tokens': 500, 'total_tokens': 551, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}})

# %%
response.usage_metadata
# Out:
# {'input_tokens': 51,
#  'output_tokens': 1000,
#  'total_tokens': 1051,
#  'input_token_details': {'cache_creation': 0, 'cache_read': 0}}
